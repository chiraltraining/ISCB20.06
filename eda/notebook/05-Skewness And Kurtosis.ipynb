# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_style('whitegrid')

# %%
df = pd.read_csv('../data/500_Person_Gender_Height_Weight_Index.csv')
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df[['Height']].plot(kind = 'hist',title = 'Height', figsize=(10,6))
plt.show()

# %%
df[['Weight']].plot(kind = 'hist',title = 'weight', figsize=(10,6))
plt.show()

# %%
df[['Height']].plot(kind = 'kde',title = 'Height', figsize=(10,6))
plt.show()

# %%
df[['Weight']].plot(kind = 'kde',title = 'Weight', figsize=(10.,6))
plt.show()

# %% [markdown]
# ## Skewness
#
# It is the degree of distortion from the normal distribution. It measures the lack of symmetry in data distribution.
#
# - Positive Skewness means when the tail on the right side of the distribution is longer or fatter. The mean and median will be greater than the mode.
#
# - Negative Skewness is when the tail of the left side of the distribution is longer or fatter than the tail on the right side. The mean and median will be less than the mode.

# %%
df['Height'].skew()
# Out:
# -0.12191368980139153

# %%
df['Height'].mean()
# Out:
# 169.944

# %%
df['Height'].median()
# Out:
# 170.5

# %%
from statistics import mode 
mode(df['Height'])
# Out:
# 188

# %%
df['Weight'].skew()
# Out:
# -0.037692236922098034

# %%
listOfSeries = [pd.Series(['Male', 400, 300, 1], index=df.columns ), 
                pd.Series(['Female', 660, 370, 2], index=df.columns ), 
                pd.Series(['Female', 199, 410, 1], index=df.columns ),
                pd.Series(['Male', 202, 390, 2], index=df.columns ), 
                pd.Series(['Female', 770, 210, 2], index=df.columns ),
                pd.Series(['Male', 880, 203, 3], index=df.columns )]

# %%
height_weight_updated = df.append(listOfSeries , ignore_index=True)

height_weight_updated.tail()
# Out:
#      Gender  Height  Weight  Index
# 501  Female     660     370      2
# 502  Female     199     410      1
# 503    Male     202     390      2
# 504  Female     770     210      2
# 505    Male     880     203      3

# %%
height_weight_updated[['Height']].plot(kind = 'hist', bins=100,
                                       title = 'Height', figsize=(10,6))
plt.show()

# %%
height_weight_updated[['Weight']].plot(kind = 'hist', bins=100,
                                       title = 'weight', figsize=(10,6))
plt.show()

# %%
height_weight_updated[['Height']].plot(kind = 'kde',
                                       title = 'Height', figsize=(10,6))
plt.show()

# %%
height_weight_updated[['Weight']].plot(kind = 'kde',
                                       title = 'weight', figsize=(10,6))
plt.show()

# %%
height_weight_updated['Height'].skew()
# Out:
# 10.660224883698124

# %%
height_weight_updated['Weight'].skew()
# Out:
# 2.185178506158764

# %% [markdown]
# ## Kurtosis
#
# It is actually the measure of outliers present in the distribution.
#
# - High kurtosis in a data set is an indicator that data has heavy tails or outliers.
# - Low kurtosis in a data set is an indicator that data has light tails or lack of outliers.

# %%
df['Height'].kurtosis()
# Out:
# -1.1196709495148123

# %%
df['Weight'].kurtosis()
# Out:
# -1.197325403294446

# %%
height_weight_updated['Height'].kurtosis()
# Out:
# 131.0892774507449

# %%
height_weight_updated['Weight'].kurtosis()
# Out:
# 13.496627294745666
